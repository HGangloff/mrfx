# %% [markdown]
# **This notebooks generates the measurements for Gibbs Chromatic sampler, time and energy, GPU and CPU**

# %% [markdown]
# *Note for CPU energy monitoring:* To get the CPU energy measure with zeus: `sudo su` then `jupyter-lab --allow-root` and modify `time_complete_sampling()` such that `gpu_energy` becomes `cpu_energy`. We also set `cpu_device = jax.devices('cpu')[0]` and `with jax.default_device(cpu_device):` because we cannot set `jax_platforms=cpu`: if we totally hide the GPU, zeus will complain.

# %%
import jax
import numpy as np
from mrfx.experiments import time_complete_sampling, plot_benchmark
from mrfx.samplers import ChromaticGibbsSampler
from mrfx.models import Potts

cpu_device = jax.devices('cpu')[0]

# %%
#with jax.default_device(cpu_device): # ACTIVATE TO GET CPU

key = jax.random.PRNGKey(0)

K = 2
beta = 1.0
potts_model = Potts(K=K, beta=beta, neigh_size=1)

Ks = np.arange(2, 8)
sizes = [(2**e, 2**e) for e in range(10, 12)]
reps = 10

key, subkey = jax.random.split(key, 2)
times, n_iterations, samples, energy = time_complete_sampling(
    ChromaticGibbsSampler,
    Potts,
    subkey,
    Ks,
    sizes,
    reps,
    kwargs_sampler={
        "eps": 0.05,
        "max_iter": 10000,
        "color_update_type": "vmap_in_color",
    },
    kwargs_model={"beta": beta},
    exp_name="Gibbs_sampler_GPU",
    with_energy=True,
)
# Out:
# [2025-09-29 16:43:23,405] [zeus.device.gpu.nvidia](nvidia.py:47) pynvml is available and initialized.
# [2025-09-29 16:43:23,412] [zeus.device.cpu.rapl](rapl.py:137) RAPL directory (/sys/class/powercap/intel-rapl) is available.
# [2025-09-29 16:43:23,413] [zeus.monitor.energy](energy.py:223) Monitoring GPU indices [0].
# [2025-09-29 16:43:23,413] [zeus.monitor.energy](energy.py:224) Monitoring CPU indices []
# Rep ( / 10):
# /home/hugo/Documents/recherche/gum/code/mrfx/mrfx/experiments/_benchmark.py:216: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   model = Model(K=k, **kwargs_model)
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# [2025-09-29 16:43:30,533] [zeus.utils.framework](framework.py:47) JAX with CUDA support is available.
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(2), lx=1024, ly=1024, compilation_time=7.117081880569458,runtime_mean=5.914766597747803, n_iter_mean=31.0, energy_mean=146.00539999999745
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(2), lx=2048, ly=2048, compilation_time=17.487141370773315,runtime_mean=16.48189768791199, n_iter_mean=31.0, energy_mean=507.81389999999953
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(3), lx=1024, ly=1024, compilation_time=9.79925274848938,runtime_mean=9.645871114730834, n_iter_mean=60.0, energy_mean=275.7039000000019
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(3), lx=2048, ly=2048, compilation_time=34.338045597076416,runtime_mean=34.12652056217193, n_iter_mean=59.8, energy_mean=1115.643100000004
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(4), lx=1024, ly=1024, compilation_time=14.081908464431763,runtime_mean=13.756337666511536, n_iter_mean=88.5, energy_mean=417.61840000000086
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(4), lx=2048, ly=2048, compilation_time=53.45981812477112,runtime_mean=54.433378148078916, n_iter_mean=89.2, energy_mean=1818.3529999999998
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(5), lx=1024, ly=1024, compilation_time=17.86660099029541,runtime_mean=17.38964960575104, n_iter_mean=117.5, energy_mean=545.3814999999944
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(5), lx=2048, ly=2048, compilation_time=72.28818869590759,runtime_mean=72.07895603179932, n_iter_mean=117.7, energy_mean=2426.1139999999955
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(6), lx=1024, ly=1024, compilation_time=21.166073322296143,runtime_mean=21.22010419368744, n_iter_mean=144.1, energy_mean=676.9472999999998
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(6), lx=2048, ly=2048, compilation_time=90.24369597434998,runtime_mean=91.60753784179687, n_iter_mean=146.2, energy_mean=3099.4630000000006
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(7), lx=1024, ly=1024, compilation_time=25.539578437805176,runtime_mean=25.20783848762512, n_iter_mean=172.3, energy_mean=814.226800000004
# Rep ( / 10): Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 1 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 2 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 3 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 4 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 5 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 6 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 7 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 8 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 9 Stopping chromatic Gibbs sampler, cause: Convergence criterion is reached
# 10
# k=np.int64(7), lx=2048, ly=2048, compilation_time=111.071129322052,runtime_mean=109.84247276782989, n_iter_mean=173.3, energy_mean=3732.495500000002

# %%
plot_benchmark(
    Ks, sizes, times, title="Times for Chromatic Gibbs sampling", ylabel="times (s)"
)

# %%
plot_benchmark(
    Ks, sizes, energy, title="Energy for Chromatic Gibbs sampling", ylabel="energy (J)"
)
